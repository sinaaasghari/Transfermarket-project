# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("All_player_with_score.csv")

# %%
df.drop(['Unnamed: 0.1', 'Unnamed: 0','position', 'agent'], axis=1, inplace=True)

# %%
df.fillna(0 ,inplace=True)
df.drop('date_of_birth', axis=1 , inplace=True)

# %%
df = df.drop_duplicates(['player_name']).reset_index()

# %%
df_filterd = df.drop(['index', 'season_id', 'player_id','player_name'], axis=1)
df_filterd
# Out:
#           goals    assists        ppg  yellow_cards  second_yellow_cards  \
# 0     31.707317  90.909091  74.333333     38.709677                18.75
# 1     21.951220  72.727273  70.000000     35.483871                12.50
# 2     14.634146  72.727273  69.333333     32.258065                31.25
# 3     39.024390  63.636364  68.666667     22.580645                31.25
# 4     17.073171  63.636364  55.666667     32.258065                 0.00
# ...         ...        ...        ...           ...                  ...
# 6529   0.000000   0.000000   0.000000      0.000000                 0.00
# 6530   0.000000   0.000000   0.000000      0.000000                 0.00
# 6531   0.000000   0.000000   0.000000      0.000000                 0.00
# 6532   0.000000   0.000000   0.000000      0.000000                 0.00
# 6533   0.000000   0.000000   0.000000     14.285714                 0.00
#
#       red_cards  height   foot   age    mk_value    apprance       score  \
# 0           0.0    1.81  right  24.0  60000000.0   97.222222  100.000000
# 1           0.0    1.80  right  26.0  45000000.0  100.000000   90.808163
# 2           0.0    1.83  right  25.0  28000000.0  100.000000   87.857190
# 3          50.0    1.79  right  24.0  48000000.0  100.000000   86.105966
# 4           0.0    1.85  right  25.0  25000000.0   97.058824   83.221953
# ...         ...     ...    ...   ...         ...         ...         ...
# 6529        0.0    2.00  right  19.0     50000.0    0.000000    7.612532
# 6530        0.0    1.90   left  31.0    300000.0    5.000000    7.311377
# 6531        0.0    1.93  right  19.0    150000.0    3.125000    6.838731
# 6532        0.0    1.88  right  32.0    300000.0    5.263158    6.802407
# 6533        0.0    1.90  right  24.0    500000.0    0.000000    6.525027
#
#       goals_conceded  clean_sheets
# 0           0.000000           0.0
# 1           0.000000           0.0
# 2           0.000000           0.0
# 3           0.000000           0.0
# 4           0.000000           0.0
# ...              ...           ...
# 6529        0.000000           0.0
# 6530        5.494505           0.0
# 6531        4.395604           0.0
# 6532        6.593407           0.0
# 6533        0.000000           0.0
#
# [6534 rows x 14 columns]

# %%
df_plt = df_filterd.drop('foot', axis=1)
len_cols = len(df_plt.columns)
fig_col = 3 
fig_row = int(np.ceil(len_cols/fig_col))
fig, ax = plt.subplots(nrows=fig_row, ncols=fig_col, figsize=(12,20))

for i in range(len_cols) : 
    row_idx = int(i//fig_col)
    col_idx = int(i%fig_col)
    sns.boxplot(df_plt.iloc[:,i], ax = ax[row_idx][col_idx], palette='magma')
    ax[row_idx][col_idx].set_title(df_plt.columns[i])

# %%
from sklearn.cluster import KMeans
max_k = 15
cost = []
for i in range(1,max_k) : 
    m = KMeans(n_clusters=i, n_init=10, init='k-means++')
    m.fit(df_plt)
    cost.append(m.inertia_)
    
    
plt.plot(range(1,max_k), cost)

# %%
m = KMeans(n_clusters=3, n_init=10, init='k-means++')
df_plt['cluster'] = m.fit_predict(df_plt)

# %%
df_plt
# Out:
#           goals    assists        ppg  yellow_cards  second_yellow_cards  \
# 0     31.707317  90.909091  74.333333     38.709677                18.75
# 1     21.951220  72.727273  70.000000     35.483871                12.50
# 2     14.634146  72.727273  69.333333     32.258065                31.25
# 3     39.024390  63.636364  68.666667     22.580645                31.25
# 4     17.073171  63.636364  55.666667     32.258065                 0.00
# ...         ...        ...        ...           ...                  ...
# 6529   0.000000   0.000000   0.000000      0.000000                 0.00
# 6530   0.000000   0.000000   0.000000      0.000000                 0.00
# 6531   0.000000   0.000000   0.000000      0.000000                 0.00
# 6532   0.000000   0.000000   0.000000      0.000000                 0.00
# 6533   0.000000   0.000000   0.000000     14.285714                 0.00
#
#       red_cards  height   age    mk_value    apprance       score  \
# 0           0.0    1.81  24.0  60000000.0   97.222222  100.000000
# 1           0.0    1.80  26.0  45000000.0  100.000000   90.808163
# 2           0.0    1.83  25.0  28000000.0  100.000000   87.857190
# 3          50.0    1.79  24.0  48000000.0  100.000000   86.105966
# 4           0.0    1.85  25.0  25000000.0   97.058824   83.221953
# ...         ...     ...   ...         ...         ...         ...
# 6529        0.0    2.00  19.0     50000.0    0.000000    7.612532
# 6530        0.0    1.90  31.0    300000.0    5.000000    7.311377
# 6531        0.0    1.93  19.0    150000.0    3.125000    6.838731
# 6532        0.0    1.88  32.0    300000.0    5.263158    6.802407
# 6533        0.0    1.90  24.0    500000.0    0.000000    6.525027
#
#       goals_conceded  clean_sheets  cluster
# 0           0.000000           0.0        1
# 1           0.000000           0.0        1
# 2           0.000000           0.0        2
# 3           0.000000           0.0        1
# 4           0.000000           0.0        2
# ...              ...           ...      ...
# 6529        0.000000           0.0        0
# 6530        5.494505           0.0        0
# 6531        4.395604           0.0        0
# 6532        6.593407           0.0        0
# 6533        0.000000           0.0        0
#
# [6534 rows x 14 columns]

# %%
from sklearn.decomposition import PCA

X = df_plt.drop('cluster', axis=1)
pca_transformer = PCA(n_components=2,)

pca_transformer.fit(X)
# Out:
# PCA(n_components=2)

# %%
reduced_X = pca_transformer.transform(X)
reduced_X
# Out:
# array([[ 5.50127954e+07,  1.68151302e+01],
#        [ 4.00127954e+07, -4.55616287e+00],
#        [ 2.30127954e+07, -3.69403423e+01],
#        ...,
#        [-4.83720462e+06,  6.10623749e+01],
#        [-4.68720462e+06,  5.89074669e+01],
#        [-4.48720462e+06,  6.14279049e+01]])

# %%
reduced_df = pd.DataFrame(reduced_X, columns=['col1', 'col2'])
reduced_df['cluster'] = df_plt.cluster
reduced_df
# Out:
#               col1       col2  cluster
# 0     5.501280e+07  16.815130        1
# 1     4.001280e+07  -4.556163        1
# 2     2.301280e+07 -36.940342        2
# 3     4.301280e+07   1.325538        1
# 4     2.001280e+07 -28.322131        2
# ...            ...        ...      ...
# 6529 -4.937205e+06  63.262116        0
# 6530 -4.687205e+06  58.994113        0
# 6531 -4.837205e+06  61.062375        0
# 6532 -4.687205e+06  58.907467        0
# 6533 -4.487205e+06  61.427905        0
#
# [6534 rows x 3 columns]

# %%
sns.set_style("whitegrid")  # You can choose different styles like "white", "darkgrid", "ticks", etc.
sns.set_palette("Set2")
plt.figure(figsize=(20, 10))
sns.scatterplot(data=reduced_df, x='col1', y='col2', hue='cluster')
plt.show()

# %%
df['cluster'] = df_plt.cluster

# %%
df
# Out:
#       index  season_id  player_id      goals    assists        ppg  \
# 0         0       2019      88755  31.707317  90.909091  74.333333
# 1        16       2021      35207  21.951220  72.727273  70.000000
# 2        23       2019     128220  14.634146  72.727273  69.333333
# 3        37       2019     240306  39.024390  63.636364  68.666667
# 4        47       2018     187492  17.073171  63.636364  55.666667
# ...     ...        ...        ...        ...        ...        ...
# 6529  80108       2019     300582   0.000000   0.000000   0.000000
# 6530  80146       2021      55000   0.000000   0.000000   0.000000
# 6531  80187       2019     284270   0.000000   0.000000   0.000000
# 6532  80200       2017      19958   0.000000   0.000000   0.000000
# 6533  80237       2020     250683   0.000000   0.000000   0.000000
#
#       yellow_cards  second_yellow_cards  red_cards        player_name  height  \
# 0        38.709677                18.75        0.0    Kevin De Bruyne    1.81
# 1        35.483871                12.50        0.0         Marco Reus    1.80
# 2        32.258065                31.25        0.0       Luis Alberto    1.83
# 3        22.580645                31.25       50.0    Bruno Fernandes    1.79
# 4        32.258065                 0.00        0.0      Julian Brandt    1.85
# ...            ...                  ...        ...                ...     ...
# 6529      0.000000                 0.00        0.0         Jonas Hupe    2.00
# 6530      0.000000                 0.00        0.0  Vincenzo Fiorillo    1.90
# 6531      0.000000                 0.00        0.0     Moritz Nicolas    1.93
# 6532      0.000000                 0.00        0.0    Nereo Champagne    1.88
# 6533     14.285714                 0.00        0.0     Nikita Contini    1.90
#
#        foot   age    mk_value    apprance       score  goals_conceded  \
# 0     right  24.0  60000000.0   97.222222  100.000000        0.000000
# 1     right  26.0  45000000.0  100.000000   90.808163        0.000000
# 2     right  25.0  28000000.0  100.000000   87.857190        0.000000
# 3     right  24.0  48000000.0  100.000000   86.105966        0.000000
# 4     right  25.0  25000000.0   97.058824   83.221953        0.000000
# ...     ...   ...         ...         ...         ...             ...
# 6529  right  19.0     50000.0    0.000000    7.612532        0.000000
# 6530   left  31.0    300000.0    5.000000    7.311377        5.494505
# 6531  right  19.0    150000.0    3.125000    6.838731        4.395604
# 6532  right  32.0    300000.0    5.263158    6.802407        6.593407
# 6533  right  24.0    500000.0    0.000000    6.525027        0.000000
#
#       clean_sheets  cluster
# 0              0.0        1
# 1              0.0        1
# 2              0.0        2
# 3              0.0        1
# 4              0.0        2
# ...            ...      ...
# 6529           0.0        0
# 6530           0.0        0
# 6531           0.0        0
# 6532           0.0        0
# 6533           0.0        0
#
# [6534 rows x 19 columns]

# %%
for cluster in range(3):
    print(f"\nCluster {cluster}:")
    cluster_df = df[df["cluster"] == cluster]
    country_values = cluster_df["player_name"].unique()
    print("Countries:", country_values)
# Out:
# Cluster 0:
# Countries: ['Henrikh Mkhitaryan' 'Jonathan Viera' 'Lars Stindl' ... 'Moritz Nicolas'
#  'Nereo Champagne' 'Nikita Contini']
#
# Cluster 1:
# Countries: ['Kevin De Bruyne' 'Marco Reus' 'Bruno Fernandes' 'Aaron Ramsey'
#  'Paul Pogba' 'Bernardo Silva' 'Leon Goretzka' 'Mason Mount' 'Dani Olmo'
#  'James Rodríguez' 'James Maddison' 'Kai Havertz' 'Jude Bellingham'
#  'Youri Tielemans' 'Toni Kroos' 'Naby Keïta' 'Isco' 'Koke' 'Ivan Rakitic'
#  'Frenkie de Jong' 'Federico Valverde' 'Marco Verratti' 'Pedri'
#  'Eduardo Camavinga' 'Gavi' 'Arthur Melo' 'Robert Lewandowski'
#  'Lionel Messi' 'Mohamed Salah' 'Erling Haaland' 'Harry Kane'
#  'Timo Werner' 'Cristiano Ronaldo' 'Jadon Sancho' 'Paulo Dybala'
#  'Karim Benzema' 'Mauro Icardi' 'Sadio Mané' 'Raheem Sterling'
#  'Luis Suárez' 'Lautaro Martínez' 'Marcus Rashford' 'Luis Díaz'
#  'Philippe Coutinho' 'Gabriel Jesus' 'Memphis Depay' 'Neymar'
#  'Florian Thauvin' 'Diogo Jota' 'Dusan Vlahovic' 'Riyad Mahrez'
#  'Álvaro Morata' 'Sergio Agüero' 'Vinicius Junior' 'Leroy Sané'
#  'Tammy Abraham' 'Antoine Griezmann' 'Leon Bailey' 'Federico Chiesa'
#  'Eden Hazard' 'Ángel Di María' 'Richarlison' 'Phil Foden'
#  'Christian Pulisic' 'Ferran Torres' 'Ángel Correa' 'Jonathan David'
#  'João Félix' 'Rodrygo' 'Virgil van Dijk' 'David Alaba' 'Andrew Robertson'
#  'Tomas Soucek' 'Joshua Kimmich' 'Raphaël Varane' 'Alex Sandro'
#  'John Stones' 'Declan Rice' 'Alphonso Davies' 'Kalidou Koulibaly'
#  'Rúben Dias' 'Rodri' 'Fabinho' 'Matthijs de Ligt' 'João Cancelo'
#  'Thomas Partey' 'Wilfred Ndidi' 'Marcelo Brozovic' 'Rúben Neves'
#  'José María Giménez' 'Daniel Carvajal' 'Gerard Piqué' 'José Gayà'
#  'Sergio Busquets' 'Casemiro' 'Alisson' 'Ederson' 'Jan Oblak'
#  'Thibaut Courtois']
#
# Cluster 2:
# Countries: ['Luis Alberto' 'Julian Brandt' 'Christian Eriksen' 'Ivan Perisic'
#  'Ruslan Malinovskyi' 'Adem Ljajić' 'Dele Alli' 'Filip Kostic'
#  'Josip Ilicic' 'Piotr Zielinski' 'Téji Savanier' 'Paulinho'
#  'Juan Cuadrado' 'Hakan Calhanoglu' 'Marcel Sabitzer'
#  'Benjamin Bourigeaud' 'Rodrigo de Paul' 'David Silva'
#  'Dominik Szoboszlai' 'Franck Kessié' 'Marcos Llorente' 'Robin Gosens'
#  'Antonio Candreva' 'Giovanni Reyna' 'Pablo Fornals' 'Maximilian Arnold'
#  'Alex Oxlade-Chamberlain' 'Jordan Henderson' 'Santi Cazorla'
#  'Davy Klaassen' 'Florian Neuhaus' 'Joelinton' 'Gylfi Sigurdsson'
#  'Thomas Lemar' 'Radja Nainggolan' 'Maximilian Eggestein' 'Manuel Lanzini'
#  'Lovro Majer' 'Mateo Kovacic' 'Nicolò Barella' 'Ilkay Gündogan'
#  'Nadiem Amiri' 'Arne Maier' 'Aleksandr Golovin' 'Nabil Fekir'
#  'Daichi Kamada' 'Xherdan Shaqiri' 'Thomas Delaney' 'Martin Ødegaard'
#  'Jesse Lingard' 'Dani Parejo' 'Shinji Kagawa' 'Mario Pasalic' 'Thiago'
#  'Emil Forsberg' 'Iker Muniain' 'Nikola Vlasic' 'Houssem Aouar'
#  'Giacomo Bonaventura' 'Arturo Vidal' 'John McGinn' 'José Campaña'
#  'Mattéo Guendouzi' 'Ruben Loftus-Cheek' 'Eberechi Eze' 'Ryan Sessegnon'
#  'Gerson' 'Marouane Fellaini' 'Pierre-Emile Höjbjerg' 'Romain Faivre'
#  'Lucas Paquetá' 'Sergio Canales' 'Corentin Tolisso' 'Emile Smith Rowe'
#  'Rodrigo Bentancur' 'Davy Pröpper' 'Konrad Laimer' 'Mousa Dembélé'
#  'João Mário' 'Georginio Wijnaldum' 'Moussa Sissoko' 'Brais Méndez'
#  'Xaver Schlager' 'Marek Hamsik' 'Conor Gallagher' 'Luka Modric'
#  'Amadou Haidara' 'Mahmoud Dahoud' 'Blaise Matuidi' 'Remo Freuler'
#  'Weston McKennie' 'Dennis Praet' 'Orel Mangala' 'Jean Michaël Seri'
#  'Stefano Sensi' 'Renato Sanches' 'Sander Berge' 'Eljif Elmas'
#  'Tanguy Ndombélé' 'Badou Ndiaye' 'Granit Xhaka' 'Yusuf Yazici'
#  'Nahitan Nández' 'Giovani Lo Celso' 'Brahim Díaz' 'Gedson Fernandes'
#  'Angelo Fulgini' 'Oihan Sancet' 'Enock Mwepu' 'Matías Vecino'
#  'Kevin Kampl' 'Exequiel Palacios' 'Éver Banega' 'Jonjo Shelvey'
#  'Razvan Marin' 'Adrien Rabiot' 'Matteo Pessina' 'Ross Barkley'
#  'Wylan Cyprien' 'Jeff Reine-Adélaïde' 'Enis Bardhi' 'Cesc Fàbregas'
#  'Adam Lallana' 'Saúl Ñíguez' 'André Gomes' 'Mikel Merino' 'Joan Jordán'
#  'Denzel Dumfries' 'Franco Vázquez' 'Kevin Mirallas' 'Mauro Arambarri'
#  'Borja Valero' 'Dani Ceballos' 'Alex Iwobi' 'Ivan Ilic' 'Óscar Rodríguez'
#  'Adrien Silva' 'Todd Cantwell' 'Jack Wilshere' 'Ander Herrera'
#  'Pape Matar Sarr' 'Yves Bissouma' 'Joe Willock' 'Davide Frattesi'
#  'Max Meyer' 'Nicolás Domínguez' 'Sean Longstaff' 'Lewis Cook'
#  'Philip Billing' 'Mesut Özil' 'Fred' 'Tommaso Pobega' 'Yangel Herrera'
#  'Éderson' 'Yohan Cabaye' 'Curtis Jones' 'Ainsley Maitland-Niles'
#  'Unai López' 'Carles Aleñá' 'Claudio Marchisio' 'Fran Beltrán'
#  'Rayan Cherki' 'Nico González' 'Donny van de Beek' 'Yunus Musah'
#  'Reinier' 'Samir Nasri' 'Albert Sambi Lokonga' 'André Silva'
#  'Romelu Lukaku' 'Thomas Müller' 'Christopher Nkunku' 'Heung-min Son'
#  'Luis Muriel' 'Jamie Vardy' 'Pierre-Emerick Aubameyang' 'Lorenzo Insigne'
#  'Edinson Cavani' 'Dries Mertens' 'Kevin Volland' 'Andrej Kramaric'
#  'Sébastien Haller' 'Domenico Berardi' 'Edin Dzeko' 'Wout Weghorst'
#  'Serge Gnabry' 'Anthony Martial' 'Patrick Bamford' 'Marko Arnautovic'
#  'Callum Wilson' 'Roberto Firmino' 'José Callejón' 'Thorgan Hazard'
#  'Max Kruse' 'Salomón Rondón' 'Krzysztof Piatek' 'Yussuf Poulsen'
#  'Gonzalo Higuaín' 'Cédric Bakambu' 'Jarrod Bowen' 'Raúl Jiménez'
#  'Carlos Vela' 'Wissam Ben Yedder' 'Sasa Kalajdzic' 'Ante Rebic'
#  'Henry Onyekuru' 'Steven Bergwijn' 'Iago Aspas' 'Raphinha'
#  'Ollie Watkins' 'Jonas Hofmann' 'Arkadiusz Milik' 'Giovanni Simeone'
#  'Dejan Kulusevski' 'Moussa Dembélé' 'Alexis Sánchez' 'Karl Toko Ekambi'
#  'Alassane Plea' 'Pablo Sarabia' 'Willian' 'Jonas Wind' 'Éder'
#  'Jack Harrison' 'Bukayo Saka' 'Mario Mandzukic' 'Musa Barrow'
#  'Jean-Philippe Mateta' 'Kingsley Coman' 'Hirving Lozano' 'Moussa Diaby'
#  'Nils Petersen' 'Harvey Barnes' 'Stephan El Shaarawy' 'Wilfried Zaha'
#  'Mariano Díaz' 'Rodrigo' 'Suso' 'Jérémie Boga' 'Radamel Falcao'
#  'Ihlas Bebou' 'Matteo Politano' 'Silas' 'Marcus Thuram'
#  'Mohamed Elyounoussi' 'Arthur Cabral' 'Borja Iglesias' 'Donyell Malen'
#  'Maxi Gómez' 'Felipe Anderson' 'Carlos Vinícius' 'Matheus Cunha'
#  'Georginio Rutter' 'Jürgen Locadia' 'Rony Lopes' 'Ahmed Musa'
#  'Mikel Oyarzabal' 'Grégoire Defrel' 'Mohamed Bayo' 'Willian José'
#  'Saïd Benrahma' 'Armando Broja' 'Youssef En-Nesyri' 'Andrea Petagna'
#  'Aleksandar Mitrović' 'Breel Embolo' 'Rafael Leão' 'Paco Alcácer'
#  'Andros Townsend' 'Roberto Inglese' 'Yannick Carrasco' 'Iñaki Williams'
#  'Yannick Bolasie' 'João Pedro' 'Leandro Trossard' 'Moise Kean'
#  'Nikola Kalinic' 'Erik Lamela' 'Pedro Neto' 'Mario Balotelli'
#  'Diego Perotti' 'Emiliano Sala' 'Raúl de Tomás' 'Alexandre Lacazette'
#  'Gervinho' 'Olivier Giroud' 'Keita Baldé' 'Rafa Mir' 'Gonçalo Guedes'
#  'Tetê' 'Ousmane Dembélé' 'Lucas Moura' 'Dwight McNeil' 'Nicolás González'
#  'Andriy Yarmolenko' 'Patrik Schick' 'Allan Saint-Maximin'
#  'Jean-Kévin Augustin' 'Ismaïla Sarr' 'Juanmi' 'Santi Mina'
#  'Gianluca Scamacca' 'Kasper Dolberg' 'Josip Brekalo' 'Patrick Cutrone'
#  'Jorge de Frutos' 'Cengiz Ünder' 'Daniel Podence' 'Boulaye Dia'
#  'David Brooks' 'Vincent Janssen' 'Andreas Skov Olsen' 'Rubén Vargas'
#  'Divock Origi' 'Demarai Gray' 'Mattia Zaccagni' 'Callum Hudson-Odoi'
#  'Javairô Dilrosun' 'Jérémy Doku' 'Alexander Isak' 'Nacer Chadli'
#  'Lucas Ocampos' 'Charlie Austin' 'Guido Carrillo' 'Darío Benedetto'
#  'Sofiane Boufal' 'Michy Batshuayi' 'Krépin Diatta'
#  'Federico Bernardeschi' 'Miguel Almirón' 'Hee-chan Hwang'
#  'Ermedin Demirovic' 'Eddie Nketiah' 'Chicharito' 'Jonathan Ikoné'
#  'Michael Olise' 'Alexis Saelemaekers' 'Gabriel Martinelli'
#  'André Schürrle' 'Mikkel Damsgaard' 'Christian Benteke' 'Julian Draxler'
#  'Diego Costa' 'Marco Asensio' 'Arnaud Kalimuendo' 'Dusan Tadic'
#  'Ansu Fati' 'Wilfried Bony' 'Bruma' 'Anthony Gordon' 'Samuel Chukwueze'
#  'Bernard' 'Quincy Promes' 'Fábio Silva' 'Harry Wilson' 'Adnan Januzaj'
#  'Yéremy Pino' 'Myron Boadu' 'André Ayew' 'Gelson Martins' 'Sofiane Diop'
#  'Justin Kluivert' 'Dominic Solanke' 'Bryan Gil' 'Hakim Ziyech'
#  'Kamaldeen Sulemana' 'Tecatito' 'Youssoufa Moukoko' 'Arda Turan'
#  'Sergi Canós' 'Ander Barrenetxea' 'Daniel Sturridge' 'Vitolo' 'Trincão'
#  'Patson Daka' 'Diego Lainez' 'Momo Cho' 'Amad Diallo' 'Calvin Stengs'
#  'Saido Berahino' 'Kayky' 'Seydou Doumbia' 'Benjamin Mendy'
#  'Jean-Philippe Gbamin' 'Joe Gomez' 'Davinson Sánchez' 'Aymeric Laporte'
#  'Eric Dier' 'Maxime Gonalons' 'Joel Matip' 'Ricardo Pereira'
#  'Timothy Castagne' 'César Azpilicueta' 'Kyle Walker' 'Victor Lindelöf'
#  'Oleksandr Zinchenko' 'Elseid Hysaj' 'Matthias Ginter' 'Manuel Akanji'
#  'Edmond Tapsoba' 'Lucas Hernández' 'Joakim Maehle' 'Chris Smalling'
#  'Lukas Klostermann' 'Leonardo Bonucci' 'Nico Elvedi' 'Jonathan Tah'
#  'Raphaël Guerreiro' 'Ömer Toprak' 'Abdul-Rahman Baba' 'Benjamin Pavard'
#  'Caglar Söyüncü' 'Moussa Niakhaté' 'Lucas Digne' 'Fernandinho'
#  'Leonardo Spinazzola' 'Kieran Tierney' 'Tyler Adams' 'Takehiro Tomiyasu'
#  'Ben Chilwell' 'Allan' 'Toby Alderweireld' 'Philipp Lienhart'
#  'Hans Hateboer' 'James Justin' 'Luke Thomas' 'Jonny Otto' 'Phil Jones'
#  'Robin Koch' 'Jan Vertonghen' 'William Saliba' 'Mateo Musacchio'
#  'Harry Winks' 'Matt Doherty' 'Mats Hummels' 'Dayot Upamecano'
#  'Waldemar Anton' 'Vladimir Coufal' 'Reece James' 'Thiago Silva'
#  'Eric García' 'Ridle Baku' 'Juan Bernat' 'Odilon Kossounou' 'Jack Cork'
#  'Ellyes Skhiri' 'Kurt Zouma' 'Leighton Baines' 'Alessandro Florenzi'
#  'Ibrahima Konaté' 'Merih Demiral' 'Jeremie Frimpong' 'Martin Hinteregger'
#  'Daley Blind' 'Manuel Lazzari' 'Davide Zappacosta' 'Héctor Bellerín'
#  'Ethan Pinnock' 'Marko Grujic' 'Emre Can' 'Vitaliy Mykolenko'
#  'Nordi Mukiele' 'Sead Kolasinac' 'John Anthony Brooks' 'Lewis Dunk'
#  'Diego Llorente' 'Antonio Rüdiger' 'Yerry Mina' 'Stefan Lainer'
#  'Thomas Meunier' 'Angeliño' 'Niklas Stark' 'Jannik Vestergaard'
#  'Dejan Lovren' 'Ben Davies' 'Andreas Christensen' 'James Tarkowski'
#  'Michael Keane' 'Conor Coady' 'Nélson Semedo' 'Ismaël Bennacer'
#  'Ben Godfrey' 'Harry Maguire' 'Jérôme Roussillon' 'Joachim Andersen'
#  'Thilo Kehrer' 'Marcos Alonso' 'Denis Zakaria' 'Oliver Skipp'
#  'Fabián Balbuena' 'Jonny Evans' 'Shkodran Mustafi' 'Nico Schlotterbeck'
#  'Maxence Lacroix' 'Alessio Romagnoli' 'Nico Schulz' 'Danny da Costa'
#  'Sebastiaan Bornauw' 'Morgan Schneiderlin' 'Jamaal Lascelles'
#  'Benjamin Henrichs' 'Alex Telles' 'Valentino Lazaro' 'Leander Dendoncker'
#  'Danilo' 'Rico Henry' 'Piero Hincapié' 'Wesley Fofana' 'Diego Demme'
#  'Nahuel Molina' 'Shane Duffy' 'Marten de Roon' 'Diego Godín'
#  'Philipp Max' 'Ricardo Rodríguez' 'Jan Bednarek' 'Cheikhou Kouyaté'
#  'Julian Weigl' 'Sandro Tonali' 'Mitchel Bakker'
#  'Sokratis Papastathopoulos' 'Vincent Kompany' 'Giovanni Di Lorenzo'
#  'Amir Rrahmani' 'Salih Özcan' 'Boubakary Soumaré' 'Tariq Lamptey'
#  'Adam Webster' 'Gian Marco Ferrari' 'Luke Shaw' 'Dan Burn'
#  'Mohamed Simakan' 'David Raum' 'Bryan Cristante' 'Wendell'
#  'Lucas Tousart' 'Marquinhos' 'Francis Coquelin' 'Theo Hernández'
#  'Jason Denayer' 'Emerson Royal' 'Alessandro Bastoni' 'Mattia Caldara'
#  'Kalvin Phillips' 'Marc Cucurella' 'Ramy Bensebaini' 'Sergio Reguilón'
#  'Stanislav Lobotka' 'Matija Nastasic' 'Rob Holding' 'Pascal Struijk'
#  'Marcos Rojo' 'Diadié Samassékou' 'Nuno Tavares' 'Bruno Guimarães'
#  'Vitaly Janelt' 'Malang Sarr' 'Josko Gvardiol' 'Steven Nzonzi'
#  'Ferland Mendy' 'Sergi Roberto' 'Cristian Romero' 'Axel Disasi'
#  'Tyrone Mings' 'Brandon Williams' 'Panagiotis Retsos' 'Rayan Aït-Nouri'
#  'Nikola Milenkovic' 'Tuta' 'Kristoffer Ajer' 'Juan Foyth' 'Caio Henrique'
#  'Nayef Aguerd' 'Matty Cash' 'Ruben Aguilar' 'Sven Botman'
#  'Christian Nörgaard' 'Yeray Álvarez' 'Asier Illarramendi'
#  'Martín Zubimendi' 'Evan Ndicka' 'Konstantinos Tsimikas'
#  'Grzegorz Krychowiak' 'Luka Milivojevic' 'Tiemoué Bakayoko'
#  'Gianluca Mancini' 'Youcef Atal' 'Gabriel Paulista' 'Vanderson'
#  'Max Aarons' 'Geoffrey Kondogbia' 'Mohammed Salisu' 'Pierre Kalulu'
#  'Marcelo' 'Stefan de Vrij' 'Pervis Estupiñán' 'Colin Dagba'
#  'Guillermo Maripán' 'Zeki Celik' 'Aaron Hickey' 'Reinildo Mandava'
#  'Wesley Hoedt' 'Jordi Alba' 'Robin Le Normand' 'Lucas Martínez Quarta'
#  'Benoît Badiashile' 'Marash Kumbulla' 'Danilo Pereira' 'Alfonso Pedraza'
#  'Aritz Elustondo' 'Álex Moreno' 'Iñigo Martínez' 'Domingos Duarte'
#  'Éder Militão' 'Igor' 'Yuri Berchiche' 'Marcos Acuña' 'Samuele Ricci'
#  'Mouctar Diakhaby' 'Sergiño Dest' 'Boubacar Kamara' 'Mario Hermoso'
#  'Khéphren Thuram' 'Álvaro Odriozola' 'Tiago Djaló' 'Ronald Araújo'
#  'Duje Caleta-Car' 'Teun Koopmeiners' 'Maxime López' 'Stefan Savic'
#  'Mathías Olivera' 'Benjamin André' 'Cheick Doucouré' 'Sofyan Amrabat'
#  'William Carvalho' 'Abdou Diallo' 'Nuno Mendes' 'Jonathan Clauss'
#  'Adrien Truffert' 'Víctor Ruiz' 'Renan Lodi' 'Stephane Singo'
#  'Luiz Gustavo' 'Jefferson Lerma' 'Eliaquim Mangala' 'Juanfran Torres'
#  'Guido Rodríguez' 'Pape Gueye' 'Gonzalo Montiel' 'Loïc Badé'
#  'Arthur Theate' 'Simon Mignolet' 'David de Gea' 'Manuel Neuer'
#  'Mike Maignan' 'Koen Casteels' 'Edouard Mendy' 'Gianluigi Donnarumma'
#  'Keylor Navas' 'Marc-André ter Stegen' 'Wojciech Szczesny' 'David Raya'
#  'Robert Sánchez' 'Kepa Arrizabalaga' 'Alphonse Areola' 'Aaron Ramsdale'
#  'Álex Remiro' 'Benjamin Lecomte' 'Nick Pope' 'Bernd Leno' 'David Soria'
#  'Jordan Pickford' 'Pierluigi Gollini' 'José Sá' 'Anthony Lopes'
#  'Juan Musso' 'Unai Simón' 'Illan Meslier' 'Bartlomiej Dragowski'
#  'Pau López' 'Rui Silva' 'Luís Maximiano' 'Sergio Rico']
